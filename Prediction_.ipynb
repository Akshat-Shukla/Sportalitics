# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshat-Shukla/Sportalitics/blob/main/Prediction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/Akshat-Shukla/Sportalitics/main/matches_final.csv"
matches = pd.read_csv(url, index_col = 0)
start_date = "2023-01-01"
end_date = "2023-01-01"

# %%
matches["team"]
# Out:
# 1      Manchester City
# 2      Manchester City
# 3      Manchester City
# 4      Manchester City
# 5      Manchester City
#             ...
# 38    Sheffield United
# 39    Sheffield United
# 40    Sheffield United
# 41    Sheffield United
# 42    Sheffield United
# Name: team, Length: 2280, dtype: object

# %%
matches.shape
# Out:
# (2280, 27)

# %%
matches["team"].value_counts()
# Out:
# Manchester City             114
# Crystal Palace              114
# Southampton                 114
# Leeds United                114
# Leicester City              114
# Everton                     114
# West Ham United             114
# Arsenal                     114
# Chelsea                     114
# Wolverhampton Wanderers     114
# Tottenham Hotspur           114
# Aston Villa                 114
# Brighton and Hove Albion    114
# Liverpool                   114
# Newcastle United            114
# Manchester United           114
# Fulham                       76
# Brentford                    76
# Burnley                      76
# Bournemouth                  38
# Nottingham Forest            38
# Watford                      38
# Norwich City                 38
# West Bromwich Albion         38
# Sheffield United             38
# Name: team, dtype: int64

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     60
# Matchweek 30    60
# Matchweek 23    60
# Matchweek 12    60
# Matchweek 24    60
# Matchweek 25    60
# Matchweek 26    60
# Matchweek 27    60
# Matchweek 29    60
# Matchweek 31    60
# Matchweek 2     60
# Matchweek 33    60
# Matchweek 34    60
# Matchweek 28    60
# Matchweek 35    60
# Matchweek 36    60
# Matchweek 37    60
# Matchweek 32    60
# Matchweek 22    60
# Matchweek 21    60
# Matchweek 7     60
# Matchweek 20    60
# Matchweek 3     60
# Matchweek 4     60
# Matchweek 5     60
# Matchweek 6     60
# Matchweek 8     60
# Matchweek 9     60
# Matchweek 10    60
# Matchweek 11    60
# Matchweek 13    60
# Matchweek 14    60
# Matchweek 15    60
# Matchweek 16    60
# Matchweek 17    60
# Matchweek 18    60
# Matchweek 19    60
# Matchweek 38    60
# Name: round, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf                int64
# ga                int64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+","",regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split = 10, random_state = 1)

# %%
train = matches[matches["date"] < start_date]

# %%
test = matches[matches["date"] > end_date]

# %%
matches
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 38 2021-05-02  19:15  Premier League  Matchweek 34  Sun  Away      L   0   4
# 39 2021-05-08  15:00  Premier League  Matchweek 35  Sat  Home      L   0   2
# 40 2021-05-16  19:00  Premier League  Matchweek 36  Sun  Away      W   1   0
# 41 2021-05-19  18:00  Premier League  Matchweek 37  Wed  Away      L   0   1
# 42 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W   1   0
#
# ...

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)
acc
# Out:
# 0.6004672897196262

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index = combined["actual"], columns = combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           208  55
# 1           116  49

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds)
# Out:
# 0.47115384615384615

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
group
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 0  2020-09-21  20:15  Premier League   Matchweek 2  Mon  Away      W   3   1
# 2  2020-09-27  16:30  Premier League   Matchweek 3  Sun  Home      L   2   5
# 4  2020-10-03  17:30  Premier League   Matchweek 4  Sat  Away      D   1   1
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
def rolling_averages(group, cols, new_cols):
  group = group.sort_values("date")
  rolling_stats = group[cols].rolling(3, closed="left").mean()
  group[new_cols] = rolling_stats
  group = group.dropna(subset = new_cols)
  return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result  gf  ga  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W   1   0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W   1   0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D   1   1
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L   0   2
# ..        ...    ...             ...           ...  ...   ...    ...  ..  ..
# 52 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   2   1
# 54 2023-05-14  14:00  Premier League  Matchweek 36  Sun  Away      W   3   0
# 56 2023-05-21  16:00  Premier League  Matchweek 37  Sun  Home      W   1   0
# 57 2023-05-24  20:00  Premier League  Matchweek 32  Wed  Away      D   1   1
# 58 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0   1
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling = matches_rolling.droplevel("team")

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result  gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W   2
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L   0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L   0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W   1
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L   0
# ...         ...    ...             ...           ...  ...   ...    ...  ..
# 2197 2023-04-29  15:00  Premier League  Matchweek 34  Sat  Away      L   0
# 2198 2023-05-06  15:00  Premier League  Matchweek 35  Sat  Home      W   1
# 2199 2023-05-13  15:00  Premier League  Matchweek 36  Sat  Away      L   0
# 2200 2023-05-20  15:00  Premier League  Matchweek 37  Sat  Home      D   1
# 2201 2023-05-28  16:30  Premier League  Matchweek 38  Sun  Away      L   0
#
# ...

# %%
def make_predictions(data, predictors):
  train = data[data["date"]< start_date]
  test = data[data["date"]> end_date]
  rf.fit(train[predictors], train["target"])
  preds = rf.predict(test[predictors])
  combined = pd.DataFrame(dict(actual = test["target"], predicted = preds),index = test.index)
  precision = precision_score(test["target"], preds)
  return combined, precision

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.5306122448979592

# %%
combined
# Out:
#       actual  predicted
# 89         0          1
# 90         1          0
# 91         1          0
# 92         0          1
# 93         0          1
# ...      ...        ...
# 2197       0          0
# 2198       1          0
# 2199       0          0
# 2200       0          0
# 2201       0          0
#
# [428 rows x 2 columns]

# %%
matches_rolling.head()
# Out:
#         date   time            comp        round  day venue result  gf  ga  \
# 0 2020-10-04  14:00  Premier League  Matchweek 4  Sun  Home      W   2   1
# 1 2020-10-17  17:30  Premier League  Matchweek 5  Sat  Away      L   0   1
# 2 2020-10-25  19:15  Premier League  Matchweek 6  Sun  Home      L   0   1
# 3 2020-11-01  16:30  Premier League  Matchweek 7  Sun  Away      W   1   0
# 4 2020-11-08  19:15  Premier League  Matchweek 8  Sun  Home      L   0   3
#
#           opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 0    Sheffield Utd  ...         6       1    2.000000    1.333333   8.000000
# 1  Manchester City  ...         5       0    1.666667    1.666667   5.666667
# 2   Leicester City  ...         6       0    1.000000    1.666667   7.000000
# 3   Manchester Utd  ...         6       1    0.666667    1.000000   9.666667
# 4      Aston Villa  ...         6       0    0.333333    0.666667   9.666667
#
# ...

# %%
combined = combined.merge(matches_rolling[["date","team","opponent","result"]],left_index = True, right_index = True)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 89         0          1 2023-01-03                  Arsenal   Newcastle Utd
# 90         1          0 2023-01-15                  Arsenal       Tottenham
# 91         1          0 2023-01-22                  Arsenal  Manchester Utd
# 92         0          1 2023-02-04                  Arsenal         Everton
# 93         0          1 2023-02-11                  Arsenal       Brentford
# ...      ...        ...        ...                      ...             ...
# 2197       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 2198       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 2199       0          0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 2200       0          0 2023-05-20  Wolverhampton Wanderers         Everton
# 2201       0          0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result
# 89        D
# 90        W
# 91        W
# ...

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion" : "Brighton",
    "Manchester United" : "Manchester Utd",
    "Tottenham Hotspur" : "Tottenham",
    "Newcastle United" : "Newcastle Utd",
    "Wolverhampton Wanderers" : "Wolves",
    "West Ham United" : "West Ham"
}

mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
combined
# Out:
#       actual  predicted       date                     team        opponent  \
# 89         0          1 2023-01-03                  Arsenal   Newcastle Utd
# 90         1          0 2023-01-15                  Arsenal       Tottenham
# 91         1          0 2023-01-22                  Arsenal  Manchester Utd
# 92         0          1 2023-02-04                  Arsenal         Everton
# 93         0          1 2023-02-11                  Arsenal       Brentford
# ...      ...        ...        ...                      ...             ...
# 2197       0          0 2023-04-29  Wolverhampton Wanderers        Brighton
# 2198       1          0 2023-05-06  Wolverhampton Wanderers     Aston Villa
# 2199       0          0 2023-05-13  Wolverhampton Wanderers  Manchester Utd
# 2200       0          0 2023-05-20  Wolverhampton Wanderers         Everton
# 2201       0          0 2023-05-28  Wolverhampton Wanderers         Arsenal
#
#      result new_team
# 89        D  Arsenal
# ...

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            1 2023-01-03                  Arsenal
# 1           1            0 2023-01-15                  Arsenal
# 2           1            0 2023-01-22                  Arsenal
# 3           0            1 2023-02-04                  Arsenal
# 4           0            1 2023-02-11                  Arsenal
# ..        ...          ...        ...                      ...
# 402         0            0 2023-04-29  Wolverhampton Wanderers
# 403         1            0 2023-05-06  Wolverhampton Wanderers
# 404         0            0 2023-05-13  Wolverhampton Wanderers
# 405         0            0 2023-05-20  Wolverhampton Wanderers
# 406         0            0 2023-05-28  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Newcastle Utd        D    Arsenal         0            0
# 1         Tottenham        W    Arsenal         0            0
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    48
# 0    38
# Name: actual_x, dtype: int64

# %%
48 / 86
# Out:
# 0.5581395348837209
